# %%
# 조건식의 종류
# a == b: a와 b가 같다.
# a != b: a와 b가 같지 않다.
# a < b: a가 b보다 작다.
# a <= b: a가 b보다 작거나 같다.
# a > b: a가 b보다 크다.
# a >= b: a가 b보다 크거나 같다.
# a AND b: a와 b를 모두 만족한다.
# a OR b: a 또는 b 둘 중 하나를 만족한다.

# %%
# if문
# 특정 조건이 참인 경우, 수행문의 내용을 수행함.
# 문제 01. 기온이 0도보다 높으면 아이스 아메리카노를 출력하는 코드 작성하기.
temp = int(input("현재의 기온: "))

if temp > 0:
    print("아이스 아메리카노")
# Out:
# 아이스 아메리카노

# %%
# else문
# if 조건을 만족하지 않을 때 실행할 구문을 정의.
# else 뒤에 별도의 조건식 작성 X.
# 문제 02. 기온이 0도보다 높으면 '아이스 아메리카노'를 출력, 그렇지 않으면 '따뜻한 아메리카노'를 출력하는 코드 작성하기.
temp = int(input("현재의 기온: "))

if temp > 0:
    print("아이스 아메리카노")
else:
    print("따뜻한 아메리카노")
# Out:
# 따뜻한 아메리카노

# %%
# elif문
# if 조건이 거짓인 경우, 추가적으로 조건을 검사하려 할 때 사용.
# 여러 개의 elif문 연속으로 사용 가능.
# 문제 03. 기온이 0도보다 높으면 '아이스 아메리카노', 기온이 0도이면 '미지근한 아메리카노', 기온이 0도보다 낮으면 '따뜻한 아메리카노'를 출력하는 코드 작성하기.
temp = int(input("현재의 기온: "))

if temp > 0:
    print("아이스 아메리카노")
elif temp == 0:
    print("미지근한 아메리카노")
else:
    print("따뜻한 아메리카노")
# Out:
# 미지근한 아메리카노

# %%
# 중첩 if문
# if문 안에 또 다른 if문을 포함하는 구조.
# 문제 04. 날씨가 맑은 날인 경우, 기온이 0도보다 높으면 '아이스 아메리카노', 기온이 0도이면 '미지근한 아메리카노', 기온이 0도보다 낮으면 '따뜻한 아메리카노', 나머지 경우에는 '카푸치노'를 출력하는 코드 작성하기.
weather = str(input("오늘의 날씨('맑음', '흐림', '비', '눈' 중에서 한 가지 입력): "))
temp = int(input("현재 기온: "))

if weather == "맑음":
    if temp > 0:
        print("아이스 아메리카노")
    elif temp == 0:
        print("미지근한 아메리카노")
    else:
        print("따뜻한 아메리카노")
else:
    print("카푸치노")
# Out:
# 카푸치노

# %%
# 복합 조건
# and 연산자, or 연산자 사용하기.
# AND 연산자: 모든 조건이 참일 때 실행할 조건을 작성.
# OR 연산자: 조건 중 하나라도 참일 때 실행할 조건을 작성.
# 문제 05. 이번 기말고사 시험성적에 따라 용돈의 운명이 결정됨. 제시된 조건은 다음과 같음.
# 영어와 수학 둘 다 90점 이상: 용돈 인상
# 영어와 수학 둘 다 80점 이하: 용돈 삭감
# 그 외: 용돈 변화 X
# 수학 및 영어성적에 대한 변수를 각각 만들고, 점수에 따라 용돈이 변화되는 코드를 작성하기.
math_score = int(input("수학 점수: "))
eng_score = int(input("영어 점수: "))

if math_score >= 90 and eng_score >= 90:
    print("용돈 인상.")
elif math_score <= 80 and eng_score <= 80:
    print("용돈 삭감")
else:
    print("용돈 그대로 유지")
# Out:
# 용돈 삭감

# %%
# 문제 06. 문제 05를 응용한 버전
# 영어 90점 이상 또는 수학 90점 이상: 용돈 인상
# 영어 80점 이하 또는 수학 80점 이하: 용돈 삭감
# 그 외: 용돈 변화 X
# 수학 및 영어성적에 대한 변수를 각각 만들고, 점수에 따라 용돈이 변화되는 코드를 작성하기.
math_score = int(input("수학 점수: "))
eng_score = int(input("영어 점수: "))

if math_score >= 90 or eng_score >= 90:
    print("용돈 인상")
elif math_score <= 80 or eng_score <= 80:
    print("용돈 삭감")
else:
    print("용돈 그대로 유지")
# Out:
# 용돈 인상
