# %%
# matplotlib은 저수준 라이브러리, seaborn은 고수준 라이브러리.

# %%
# matplotlib은 python에서 데이터 시각화, 즉 다양한 그래프를 그리는 라이브러리를 제공하는 패키지.

# %%
# plotly는 interactive 웹 기반 시각화의 선두주자.
# 정적인 이미지가 아닌 사용자가 직접 조작할 수 있는 살아있는 그래프 제작 가능.
# 프레젠테이션 및 dashboard 구축에 탁월.
