# %%
# Streamlit이란 파이썬으로 웹 애플리케이션을 만들 수 있는 도구다.
# 기존에는 웹 페이지를 만들려면 HTML, CSS, JavaScript 등의 복잡한 언어를 사용해야 했지만, Streamlit은 파이썬 만으로도 웹 애플리케이션을 생성할 수 있다.

# %%
# Streamlit의 가장 큰 장점은 단순함.
# 복잡한 설정 또는 어려운 개념이 없음.
# 코드를 수정하면 웹페이지가 별도 배포 없이 수정 사항이 자동으로 업데이트 되어, 실시간 변화를 확인 가능.
# 데이터 분석가들이 분석 내용을 표시하는 웹 대시보드 형태로 자주 사용.

# 다양한 종류의 애플리케이션 제작 가능.
# 데이터를 시각화하고 분석 결과를 보여주는 데 뛰어남.

# %%
# import streamlit as st

# st.title('안녕하세요, Streamlit!')
# st.write("이것은 제 첫 번째 Streamlit 애플리케이션 입니다!")

# Jupyter notebook 파일에서 되는 줄 알았는데 안 되네.
# 결국 streamlit 코드는 .py에서 작성해서 해야 함.
# Out:
# 2026-04-28 23:24:51.638 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-28 23:24:51.685
# ...
#   command:
#
#     streamlit run /home/achieveho/Venv/DataAnalysis/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2026-04-28 23:24:51.686 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-28 23:24:51.686 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-28 23:24:51.687 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-28 23:24:51.687 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-28 23:24:51.687 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
